# %%
import pandas as pd
import numpy as np
data = pd.read_csv('advertising.csv')

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df = pd.read_csv('advertising.csv')

# %%
print(df.columns)
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.describe(include = "all")
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  False  False      False  False
# 1  False  False      False  False
# 2  False  False      False  False
# 3  False  False      False  False
# 4  False  False      False  False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# TV
# False    200
# Name: TV, dtype: int64
#
# Radio
# False    200
# Name: Radio, dtype: int64
#
# Newspaper
# False    200
# Name: Newspaper, dtype: int64
#
# Sales
# False    200
# Name: Sales, dtype: int64

# %%
df[["TV","Radio","Newspaper"]] = df[["TV","Radio","Newspaper"]].astype("int")

# %%
df.dtypes
# Out:
# TV             int64
# Radio          int64
# Newspaper      int64
# Sales        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df['Sales'].dtypes
# Out:
# dtype('float64')

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.055388   0.055569  0.901096
# Radio      0.055388  1.000000   0.352552  0.350823
# Newspaper  0.055569  0.352552   1.000000  0.157477
# Sales      0.901096  0.350823   0.157477  1.000000

# %%
sns.regplot(x="TV", y="Sales", data=df)
plt.ylim(0,)
# Out:
# (0.0, 28.27)

# %%
sns.regplot(x="Radio", y="Sales", data=df)
plt.ylim(0,)
# Out:
# (0.0, 28.27)

# %%
sns.regplot(x="Newspaper", y="Sales", data=df)
plt.ylim(0,)
# Out:
# (0.0, 28.27)

# %%
sns.boxplot(x="TV", y="Sales", data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.boxplot(x="Radio", y="Sales", data=df)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.boxplot(x="Newspaper", y="Sales", data=df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['TV'], df['Sales'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.9010960118783665  with a P-value of P = 8.817678714681962e-74

# %%
pearson_coef, p_value = stats.pearsonr(df['Radio'], df['Sales'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.35082345148014016  with a P-value of P = 3.5224975513375503e-07

# %%
pearson_coef, p_value = stats.pearsonr(df['Newspaper'], df['Sales'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.15747723042973719  with a P-value of P = 0.0259460002725089

# %%
from sklearn.linear_model import LinearRegression

# %%
sns.pairplot(data, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.pairplot(data[['TV','Radio','Newspaper']])

# %%
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression

# %%
Ststsmodels_model = smf.ols(formula='Sales ~ TV + Radio + Newspaper', data=data)
Ststsmodels_result = Ststsmodels_model.fit()

# print the coefficients
Ststsmodels_result.params
# Out:
# Intercept    4.625124
# TV           0.054446
# Radio        0.107001
# Newspaper    0.000336
# dtype: float64

# %%
feature_cols = ['TV', 'Radio', 'Newspaper']
X = data[feature_cols]
y = data[["Sales"]]

# instantiate and fit
SkLearn_model = LinearRegression()
SkLearn_result = SkLearn_model.fit(X, y)

# print the coefficients
print(SkLearn_result.intercept_)
print(SkLearn_result.coef_)
# Out:
# [4.62512408]
# [[0.05444578 0.10700123 0.00033566]]

# %%
Ststsmodels_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     605.4
# Date:                Tue, 23 Jan 2024   Prob (F-statistic):           8.13e-99
# Time:                        14:04:46   Log-Likelihood:                -383.34
# No. Observations:                 200   AIC:                             774.7
# Df Residuals:                     196   BIC:                             787.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.6251      0.308     15.041      0.000       4.019       5.232
# TV             0.0544      0.001     39.592      0.000       0.052       0.057
# Radio          0.1070      0.008     12.604      0.000       0.090       0.124
# Newspaper      0.0003      0.006      0.058      0.954      -0.011       0.012
# ==============================================================================
# Omnibus:                       16.081   Durbin-Watson:                   2.251
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.655
# Skew:                          -0.431   Prob(JB):                     9.88e-07
# Kurtosis:                       4.605   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
